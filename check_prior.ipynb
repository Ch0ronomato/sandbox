# %%
import re, os, subprocess, copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###Load log file and remove the burnin

# %%
dat_log = pd.read_csv('p1.log', sep = '\t', comment = '#', header = 2)
dat_log = dat_log.ix[int(round(shape(dat_log)[0] * 0.1, 0)):shape(dat_log)[0], :]

# %% [markdown]
# ###Plot the histograms and print hpds for priors.
# The data in blue are those that were constrained in the xml file. Those in red had uniform priors and were producing -Inf posterior. So I used a unform prior with boudnds 0 to 1000 Mya. Please check these. With the calibrations defined before the prior did not run.

# %%
unbounded_priors = ['tmrcs(AleocharaTriboliumMeloeDendroctonus)', 'tmrca(ColeopteraStrepsiptera)', 'tmrca(Dicondylia)', 'tmrca(Diplura)', 'tmrca(Ellipura)', 'tmrca(HemipteraSternorrhyncha except Aleyrodidae)', 'tmrca(Megaloptera)', 'tmrca(MegalopteraNeuroptera)', 'tmrca(Neuroptera)']
for i in times:
    print i
    hpd = [np.percentile(dat_log[i], b) for b in [0.025, 0.975]]
    print 'The prior HPD for %s is %s' %(i, hpd) 
    if i in unbounded_priors:
        print 'This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check'
        col_plot = 'red'
    else:
        col_plot = 'blue'
    dat_log[i].plot(color = col_plot)
    plt.show()
    dat_log[i].hist(color = col_plot)
    plt.show()
# Out:
# tmrca(AleocharaTriboliumMeloeDendroctonus)
# The prior HPD for tmrca(AleocharaTriboliumMeloeDendroctonus) is [14.397119855545519, 37.540439870729642]
# tmrca(BombusApis)
# The prior HPD for tmrca(BombusApis) is [24.363465020515505, 25.269419102140205]
# tmrca(CarabusGyrinus)
# The prior HPD for tmrca(CarabusGyrinus) is [207.17169526908378, 207.8507144190765]
# tmrca(ColeopteraStrepsiptera)
# The prior HPD for tmrca(ColeopteraStrepsiptera) is [216.14919223944176, 231.1921422789286]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(CopepodaBranchiopoda)
# The prior HPD for tmrca(CopepodaBranchiopoda) is [145.08458295324738, 146.31581630329316]
# tmrca(Dicondylia)
# The prior HPD for tmrca(Dicondylia) is [332.06983990556216, 348.18806705900636]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Diplura)
# The prior HPD for tmrca(Diplura) is [0.0035468600205537833, 2.051336433516223]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Diptera)
# The prior HPD for tmrca(Diptera) is [101.65546456308704, 102.48325439656608]
# tmrca(Ellipura)
# The prior HPD for tmrca(Ellipura) is [38.98885064078636, 65.927214241868725]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Embioptera)
# The prior HPD for tmrca(Embioptera) is [101.55013262672794, 102.18829597395219]
# tmrca(EmbiopteraPhasmatodea)
# The prior HPD for tmrca(EmbiopteraPhasmatodea) is [122.0125846813643, 122.61643136391933]
# tmrca(EpiophlebiaCordulegaster)
# The prior HPD for tmrca(EpiophlebiaCordulegaster) is [101.61609562132338, 102.07809320054406]
# tmrca(FormicidaeApidae)
# The prior HPD for tmrca(FormicidaeApidae) is [91.312479470009805, 92.292735641799652]
# tmrca(GlossinaSarcophagaTriarthria)
# The prior HPD for tmrca(GlossinaSarcophagaTriarthria) is [35.458866945812211, 36.242020717825099]
# tmrca(HemipteraSternorrhyncha except Aleyrodidae)
# The prior HPD for tmrca(HemipteraSternorrhyncha except Aleyrodidae) is [21.527723421275855, 36.775197244925202]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Holometabola)
# The prior HPD for tmrca(Holometabola) is [306.9261507733238, 307.61797814469742]
# tmrca(Hymenoptera)
# The prior HPD for tmrca(Hymenoptera) is [221.2036031468871, 223.49082451829889]
# tmrca(Isoptera)
# The prior HPD for tmrca(Isoptera) is [131.43044759739942, 132.08703839783436]
# tmrca(LiposcelisPediculusMenopon)
# The prior HPD for tmrca(LiposcelisPediculusMenopon) is [101.44093263826721, 102.08939016798435]
# tmrca(ManducaBombyxParidesPolyommatusZygaenaYponomeutaNemophora)
# The prior HPD for tmrca(ManducaBombyxParidesPolyommatusZygaenaYponomeutaNemophora) is [95.357123258363728, 96.582178154975509]
# tmrca(Mecoptera)
# The prior HPD for tmrca(Mecoptera) is [101.34004691463275, 102.37178316154407]
# tmrca(Megaloptera)
# The prior HPD for tmrca(Megaloptera) is [0.1260996137985157, 0.94660020080757001]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(MegalopteraNeuroptera)
# The prior HPD for tmrca(MegalopteraNeuroptera) is [18.660193391243048, 41.484676440552903]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Neuroptera)
# The prior HPD for tmrca(Neuroptera) is [1.0425385996770944, 8.0745369142132866]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Odonata)
# The prior HPD for tmrca(Odonata) is [221.09641275690382, 221.71614367740762]
# tmrca(OstracodaMalacostraca)
# The prior HPD for tmrca(OstracodaMalacostraca) is [425.06683836110108, 425.57943043557873]
# tmrca(ParidesPolyommatus)
# The prior HPD for tmrca(ParidesPolyommatus) is [35.611787330472623, 36.275886833501914]
# tmrca(PediculusMenopon)
# The prior HPD for tmrca(PediculusMenopon) is [45.917805855209416, 46.636119812751346]
# tmrca(Plecoptera)
# The prior HPD for tmrca(Plecoptera) is [161.84826252495819, 162.7401872529916]
# tmrca(Pterygota)
# The prior HPD for tmrca(Pterygota) is [326.60202552541512, 339.72743841427518]
# tmrca(RanatraVelia)
# The prior HPD for tmrca(RanatraVelia) is [101.3690454216658, 102.09082407660722]
# tmrca(SiphonapteraMecoptera)
# The prior HPD for tmrca(SiphonapteraMecoptera) is [161.90583240252809, 162.66750441289753]
# tmrca(Strepsiptera)
# The prior HPD for tmrca(Strepsiptera) is [101.3911933442546, 102.38220919318644]
# tmrca(Thysanoptera)
# The prior HPD for tmrca(Thysanoptera) is [113.54695259932726, 114.34587840525951]
# tmrca(ThysanopteraHemiptera)
# The prior HPD for tmrca(ThysanopteraHemiptera) is [207.99335237560109, 216.11186542926649]
# tmrca(ZorapteraDermaptera)
# The prior HPD for tmrca(ZorapteraDermaptera) is [161.99531561343869, 163.01459875065802]
# tmrca(Lepidoptera)
# The prior HPD for tmrca(Lepidoptera) is [113.42786686732373, 114.55622030885756]
