# %%
import re, os, subprocess, copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###Load log file and remove the burnin

# %%
dat_log = pd.read_csv('p1.log', sep = '\t', comment = '#', header = 2)
dat_log = dat_log.ix[int(round(shape(dat_log)[0] * 0.1, 0)):shape(dat_log)[0], :]

# %% [markdown]
# ###Plot the histograms and print hpds for priors.
# The data in blue are those that were constrained in the xml file. Those in red had uniform priors and were producing -Inf posterior. So I used a unform prior with boudnds 0 to 1000 Mya. Please check these. With the calibrations defined before the prior did not run.

# %%
times = [i for i in dat_log.columns if 'tmrca' in i]
unbounded_priors = ['tmrcs(AleocharaTriboliumMeloeDendroctonus)', 'tmrca(ColeopteraStrepsiptera)', 'tmrca(Dicondylia)', 'tmrca(Diplura)', 'tmrca(Ellipura)', 'tmrca(HemipteraSternorrhyncha except Aleyrodidae)', 'tmrca(Megaloptera)', 'tmrca(MegalopteraNeuroptera)', 'tmrca(Neuroptera)']
for i in times:
    print i
    hpd = [np.percentile(dat_log[i], b) for b in [0.025, 0.975]]
    print 'The prior HPD for %s is %s' %(i, hpd) 
    if i in unbounded_priors:
        print 'This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check'
        col_plot = 'red'
    else:
        col_plot = 'blue'
    dat_log[i].plot(color = col_plot)
    plt.show()
    dat_log[i].hist(color = col_plot)
    plt.show()
# Out:
# tmrca(AleocharaTriboliumMeloeDendroctonus)
# The prior HPD for tmrca(AleocharaTriboliumMeloeDendroctonus) is [14.131389428747189, 36.316700546357012]
# tmrca(BombusApis)
# The prior HPD for tmrca(BombusApis) is [23.98704660954326, 25.288785251171326]
# tmrca(CarabusGyrinus)
# The prior HPD for tmrca(CarabusGyrinus) is [207.11657048876452, 207.78726177540187]
# tmrca(ColeopteraStrepsiptera)
# The prior HPD for tmrca(ColeopteraStrepsiptera) is [216.21563928945923, 231.18473650400711]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(CopepodaBranchiopoda)
# The prior HPD for tmrca(CopepodaBranchiopoda) is [145.03682703492086, 145.98471851006187]
# tmrca(Dicondylia)
# The prior HPD for tmrca(Dicondylia) is [332.1046029018849, 349.11932878020809]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Diplura)
# The prior HPD for tmrca(Diplura) is [0.0035469402281285266, 1.5962113918715475]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Diptera)
# The prior HPD for tmrca(Diptera) is [101.35252950553004, 102.4423078314001]
# tmrca(Ellipura)
# The prior HPD for tmrca(Ellipura) is [40.311919784026834, 66.122426293632856]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Embioptera)
# The prior HPD for tmrca(Embioptera) is [101.50745181971975, 102.23408829973886]
# tmrca(EmbiopteraPhasmatodea)
# The prior HPD for tmrca(EmbiopteraPhasmatodea) is [122.01260825487832, 122.6725419498093]
# tmrca(EpiophlebiaCordulegaster)
# The prior HPD for tmrca(EpiophlebiaCordulegaster) is [101.6183575199446, 102.12337728498315]
# tmrca(FormicidaeApidae)
# The prior HPD for tmrca(FormicidaeApidae) is [91.315348634428446, 92.290026801706688]
# tmrca(GlossinaSarcophagaTriarthria)
# The prior HPD for tmrca(GlossinaSarcophagaTriarthria) is [35.428939924018515, 36.222781253897963]
# tmrca(HemipteraSternorrhyncha except Aleyrodidae)
# The prior HPD for tmrca(HemipteraSternorrhyncha except Aleyrodidae) is [21.795967897225477, 36.405644826016264]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Holometabola)
# The prior HPD for tmrca(Holometabola) is [306.92729507686431, 307.76348267172631]
# tmrca(Hymenoptera)
# The prior HPD for tmrca(Hymenoptera) is [221.18481111967156, 223.77838396056626]
# tmrca(Isoptera)
# The prior HPD for tmrca(Isoptera) is [131.43356825873965, 132.15079288868262]
# tmrca(LiposcelisPediculusMenopon)
# The prior HPD for tmrca(LiposcelisPediculusMenopon) is [101.42123438908119, 102.04792782122374]
# tmrca(ManducaBombyxParidesPolyommatusZygaenaYponomeutaNemophora)
# The prior HPD for tmrca(ManducaBombyxParidesPolyommatusZygaenaYponomeutaNemophora) is [95.357123258363728, 96.562500295405101]
# tmrca(Mecoptera)
# The prior HPD for tmrca(Mecoptera) is [101.3887858469659, 102.35371245618049]
# tmrca(Megaloptera)
# The prior HPD for tmrca(Megaloptera) is [0.13152640297564833, 0.93715386850074256]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(MegalopteraNeuroptera)
# The prior HPD for tmrca(MegalopteraNeuroptera) is [18.704162564271648, 42.997674795724066]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Neuroptera)
# The prior HPD for tmrca(Neuroptera) is [1.1549215398746668, 8.0656509421083644]
# This prior was set as a uniform. I set it with uninformative bounds between 0 and 1000 Mya. Please check
# tmrca(Odonata)
# The prior HPD for tmrca(Odonata) is [221.09698921242048, 221.62998470522004]
# tmrca(OstracodaMalacostraca)
# The prior HPD for tmrca(OstracodaMalacostraca) is [425.06712162506432, 425.58997421276916]
# tmrca(ParidesPolyommatus)
# The prior HPD for tmrca(ParidesPolyommatus) is [35.511710923316485, 36.238414669739186]
# tmrca(PediculusMenopon)
# The prior HPD for tmrca(PediculusMenopon) is [45.918525454681209, 46.628796526781251]
# tmrca(Plecoptera)
# The prior HPD for tmrca(Plecoptera) is [161.85459926936062, 162.68393820513043]
# tmrca(Pterygota)
# The prior HPD for tmrca(Pterygota) is [326.73894621251384, 340.80059390707015]
# tmrca(RanatraVelia)
# The prior HPD for tmrca(RanatraVelia) is [101.36965322842489, 102.11780928941192]
# tmrca(SiphonapteraMecoptera)
# The prior HPD for tmrca(SiphonapteraMecoptera) is [161.91283315372689, 162.6744215206308]
# tmrca(Strepsiptera)
# The prior HPD for tmrca(Strepsiptera) is [101.43498363127185, 102.41878710527075]
# tmrca(Thysanoptera)
# The prior HPD for tmrca(Thysanoptera) is [113.58060952917106, 114.35491517420584]
# tmrca(ThysanopteraHemiptera)
# The prior HPD for tmrca(ThysanopteraHemiptera) is [208.09600235785643, 215.4505488411524]
# tmrca(ZorapteraDermaptera)
# The prior HPD for tmrca(ZorapteraDermaptera) is [161.95477178535856, 162.88711226910291]
# tmrca(Lepidoptera)
# The prior HPD for tmrca(Lepidoptera) is [113.13080487254544, 114.4866739530159]

# %%
times
# Out:
# ['tmrca(AleocharaTriboliumMeloeDendroctonus)',
#  'tmrca(BombusApis)',
#  'tmrca(CarabusGyrinus)',
#  'tmrca(ColeopteraStrepsiptera)',
#  'tmrca(CopepodaBranchiopoda)',
#  'tmrca(Dicondylia)',
#  'tmrca(Diplura)',
#  'tmrca(Diptera)',
#  'tmrca(Ellipura)',
#  'tmrca(Embioptera)',
#  'tmrca(EmbiopteraPhasmatodea)',
#  'tmrca(EpiophlebiaCordulegaster)',
#  'tmrca(FormicidaeApidae)',
#  'tmrca(GlossinaSarcophagaTriarthria)',
#  'tmrca(HemipteraSternorrhyncha except Aleyrodidae)',
#  'tmrca(Holometabola)',
#  'tmrca(Hymenoptera)',
#  'tmrca(Isoptera)',
#  'tmrca(LiposcelisPediculusMenopon)',
#  'tmrca(ManducaBombyxParidesPolyommatusZygaenaYponomeutaNemophora)',
#  'tmrca(Mecoptera)',
#  'tmrca(Megaloptera)',
#  'tmrca(MegalopteraNeuroptera)',
#  'tmrca(Neuroptera)',
#  'tmrca(Odonata)',
#  'tmrca(OstracodaMalacostraca)',
#  'tmrca(ParidesPolyommatus)',
#  'tmrca(PediculusMenopon)',
#  'tmrca(Plecoptera)',
#  'tmrca(Pterygota)',
#  'tmrca(RanatraVelia)',
#  'tmrca(SiphonapteraMecoptera)',
#  'tmrca(Strepsiptera)',
#  'tmrca(Thysanoptera)',
#  'tmrca(ThysanopteraHemiptera)',
#  'tmrca(ZorapteraDermaptera)',
#  'tmrca(Lepidoptera)']
